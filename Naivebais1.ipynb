# %% [markdown]
# <a href="https://colab.research.google.com/github/harirkp006/MLOPS-TRAINING/blob/main/Naivebais1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.datasets import load_wine

wine=load_wine()

x=wine.data
y=wine.target

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=42)

from sklearn.naive_bayes import GaussianNB

modelnb=GaussianNB()
modelnb.fit(x_train,y_train)

prednb=modelnb.predict(x_test)


from sklearn.naive_bayes import MultinomialNB
modelmnb=MultinomialNB()
modelmnb.fit(x_train,y_train)

predmnbb = modelmnb.predict(x_test)

from sklearn.metrics import accuracy_score

mnb=accuracy_score(y_test,predmnbb)
print("MultinomialNB Accuracy ==>",mnb)

acc=accuracy_score(y_test,prednb)
print("GaussianNB Accuracy ==> ",acc)
# Out:
# MultinomialNB Accuracy ==> 0.8888888888888888
# GaussianNB Accuracy ==>  1.0
