# %% [markdown]
# <a href="https://colab.research.google.com/github/harirkp006/MLOPS-TRAINING/blob/main/KNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn import neighbors
import pandas as pd
from sklearn.datasets import load_digits

d=load_digits()
x=d.data
y=d.target

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
knn = KNeighborsClassifier()

grid = {
    'n_neighbors': list(range(1, 21))
}
grid_search = GridSearchCV(
    knn,
    grid,
    cv=5,
    scoring='accuracy'
)

grid_search.fit(x_train, y_train)
print(" K:", grid_search.best_params_)
print("Cross Validation Score:", grid_search.best_score_)
k = grid_search.best_params_['n_neighbors']
knnmodel = KNeighborsClassifier(n_neighbors=k)
knnmodel.fit(x_train, y_train)

from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,predknn)

import seaborn as sb
import matplotlib.pyplot as plt

sb.heatmap(cm,annot=True)

plt.figure(figsize = (10,7))

acc=accuracy_score(y_test,predknn)
print("Accuracy  ==> ",acc)
# Out:
#  K: {'n_neighbors': 1}
# Cross Validation Score: 0.9864763169544046
# Accuracy  ==>  0.9888888888888889
